# %% [markdown]
# # Case study on Supervised learning

# %% [markdown]
# Do the following in the iris dataset.
# <ol type="1">
#   <li>Read the dataset to the python environment.</li>
#   <li>Do necessary pre-processing steps.</li>
#   <li>Find out which classification model gives the best result to predict iris species.(also do random forest algorithm).</li>
# </ol>

# %% [markdown]
# # Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Reading the Dataset to the Python Environment.

# %%
data_iris = pd.read_excel("iris (2).xls")
data_iris.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  NaN  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# # Displaying the columns in the dataset.

# %%
data_iris.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # Calculating the mean of each column of the dataset.

# %%
np.mean(data_iris,axis=0)
# Out:
# SL    5.855944
# SW    3.049306
# PL    3.756250
# PW    1.198667
# dtype: float64

# %%
np.min(data_iris,axis=0)
# Out:
# SL                        4.3
# SW                        2.0
# PL                        1.0
# PW                        0.1
# Classification    Iris-setosa
# dtype: object

# %%
np.max(data_iris,axis=0)
# Out:
# SL                           7.9
# SW                           4.4
# PL                           6.9
# PW                           2.5
# Classification    Iris-virginica
# dtype: object

# %%
data_iris.shape
# Out:
# (150, 5)

# %% [markdown]
# There are 150 rows and 5 columns in the dataset.

# %% [markdown]
# # Descriptional Statistics of the dataset grouped by the data feature classification before data cleaning

# %%
pd.set_option('display.max_columns', None)
data_iris.groupby('Classification').describe()
# Out:
#                    SL                                                     SW  \
#                 count      mean       std  min    25%   50%   75%  max count
# Classification
# Iris-setosa      47.0  5.008511  0.360452  4.3  4.800  5.00  5.20  5.8  47.0
# Iris-versicolor  48.0  5.925000  0.522474  4.9  5.600  5.85  6.30  7.0  48.0
# Iris-virginica   48.0  6.616667  0.598343  5.6  6.275  6.50  6.95  7.9  49.0
#
#                                                                  PL            \
#                      mean       std  min  25%  50%   75%  max count      mean
# Classification
# Iris-setosa      3.408511  0.390557  2.3  3.1  3.4  3.65  4.4  48.0  1.468750
# Iris-versicolor  2.781250  0.315322  2.0  2.6  2.8  3.00  3.4  48.0  4.252083
# Iris-virginica   2.967347  0.322353  2.2  2.8  3.0  3.10  3.8  48.0  5.547917
#
#                                                          PW                   \
#                       std  min  25%   50%    75%  max count   mean       std
# ...

# %% [markdown]
# # Checking for the null values present in the dataset

# %%
data_iris.isna().sum()
# Out:
# SL                7
# SW                6
# PL                6
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# We can see that there are missing values in the dataset.

# %%
data_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              143 non-null    float64
#  1   SW              144 non-null    float64
#  2   PL              144 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# The values of 4 columns i.e. the SL,SW,PL,PW has numerical values while Classification has a categorical string value

# %% [markdown]
# # Checking the balance of values between different Classifications

# %%
data_iris['Classification'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Classification, dtype: int64

# %%
data_iris[data_iris.duplicated()]
# Out:
#       SL   SW   PL   PW  Classification
# 34   4.9  3.1  1.5  0.1     Iris-setosa
# 37   4.9  3.1  1.5  0.1     Iris-setosa
# 142  5.8  2.7  5.1  1.9  Iris-virginica

# %% [markdown]
# There are duplicate value in the data set iris but as seen above each classification has 50 entries each so the dataset is well balanced.

# %% [markdown]
# # Data Insights:

# %% [markdown]
# 1) Each Classification in the dataset iris is equally distributed but there are some missing values.
#
# 2) Here we can see that the mean of SL of Iris-virginica is higher than both that of Iris-versicolor and Iris-setosa.
#
# 3) But when we look into the mean value of SW, Iris-setosa has the highest mean value when compared to Iris-versicolor and Iris-virginica.
#
# 4) Iris-setosa has the least mean value for PL when compared to other classifications.Iris-virginica has the highest value.
#
# 5) Iris-virginica has the highest mean value for PW and Iris-setosa has the lowest value.

# %% [markdown]
# # Data Visualizations

# %%
plt.title('Count of Classification')
sns.countplot(x=data_iris['Classification'])
# Out:
# <AxesSubplot:title={'center':'Count of Classification'}, xlabel='Classification', ylabel='count'>

# %%
sns.pairplot(data_iris,hue='Classification')

# %% [markdown]
# # 2. Do necessary Pre-processing Steps:

# %%
#Checking for Missing Values

# %%
data_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              143 non-null    float64
#  1   SW              144 non-null    float64
#  2   PL              144 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data_iris.isna().sum()
# Out:
# SL                7
# SW                6
# PL                6
# PW                0
# Classification    0
# dtype: int64

# %%
freqgraph=data_iris.select_dtypes(include="float")
freqgraph.hist(figsize=(20,15))
plt.show()

# %%
#Handling Missing Values

# %%
data_iris['SL'] = data_iris['SL'].fillna(data_iris['PL'].mean())
data_iris['SW'] = data_iris['SW'].fillna(data_iris['PL'].mean())
data_iris['PL'] = data_iris['PL'].fillna(data_iris['PL'].mean())

# %%
data_iris.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
#Handling Outliers

# %%
fig, axes = plt.subplots(2, 2, figsize=(16,9))
sns.boxplot( y=data_iris['PL'], x= 'Classification', data=data_iris, orient='v' , ax=axes[0, 0])
sns.boxplot( y=data_iris['PW'], x= 'Classification', data=data_iris, orient='v' , ax=axes[0, 1])
sns.boxplot( y=data_iris['SL'], x= 'Classification', data=data_iris, orient='v' , ax=axes[1, 0])
sns.boxplot( y=data_iris['SW'], x= 'Classification', data=data_iris, orient='v' , ax=axes[1, 1])
plt.show()

# %%
for column in data_iris.columns[0:4]:
    for classification in data_iris["Classification"].unique():
        class_type = data_iris[data_iris["Classification"] == classification]
        Selected_column = class_type[column]
        q1 = Selected_column.quantile(0.25) # for select first quartile
        q3 = Selected_column.quantile(0.75) # for select third quartile
        iqr = q3 - q1 # this is interquartile range
        upper_limit = q3 + 1.5 * iqr
        lower_limit = q1 - 1.5 * iqr        
        outlierss = Selected_column[(Selected_column > upper_limit) | (Selected_column < lower_limit)].index # picking outliers' indeces
        print(outlierss)
        data_iris.drop(index = outlierss, inplace=True) # dropping outliers
# Out:
# Int64Index([2, 21, 39], dtype='int64')
# Int64Index([51, 85], dtype='int64')
# Int64Index([106, 141], dtype='int64')
# Int64Index([], dtype='int64')
# Int64Index([72, 98], dtype='int64')
# Int64Index([], dtype='int64')
# Int64Index([22, 28, 42], dtype='int64')
# Int64Index([], dtype='int64')
# Int64Index([109, 147], dtype='int64')
# Int64Index([23, 43], dtype='int64')
# Int64Index([], dtype='int64')
# Int64Index([], dtype='int64')

# %%
fig, axes = plt.subplots(2, 2, figsize=(16,9))
sns.boxplot( y=data_iris['PL'], x= 'Classification', data=data_iris, orient='v' , ax=axes[0, 0])
sns.boxplot( y=data_iris['PW'], x= 'Classification', data=data_iris, orient='v' , ax=axes[0, 1])
sns.boxplot( y=data_iris['SL'], x= 'Classification', data=data_iris, orient='v' , ax=axes[1, 0])
sns.boxplot( y=data_iris['SW'], x= 'Classification', data=data_iris, orient='v' , ax=axes[1, 1])
plt.show()

# %% [markdown]
# The contained outliers of the features SL, SW Pl and PW were removed.

# %%
# Label Encoding

# %%
data_iris.Classification.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
label_en = LabelEncoder()
data_iris['Classification'] = label_en.fit_transform(data_iris['Classification'])

# %%
data_iris
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2               0
# 1    4.9  3.0  1.4  0.2               0
# 3    4.6  3.1  1.5  0.2               0
# 4    5.0  3.6  1.4  0.2               0
# 5    5.4  3.9  1.7  0.4               0
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.3  5.7  2.5               2
# 145  6.7  3.0  5.2  2.3               2
# 146  6.3  2.5  5.0  1.9               2
# 148  6.2  3.4  5.4  2.3               2
# 149  5.9  3.0  5.1  1.8               2
#
# [134 rows x 5 columns]

# %%
corrmatrix = data_iris.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(corrmatrix,vmin=0.4,vmax=0.9,annot=True,linewidths=0.2,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
data_iris.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
y = data_iris['Classification']
x = data_iris.drop('Classification',axis=1)

# %%
#Feature Engineering

# %%
x['mean'] = x[['SW', 'SL', 'PW', 'PL']].mean(axis = 1)
x['sum'] = x[['SW', 'SL', 'PW', 'PL']].sum(axis = 1)
x['skew'] = x[['SW', 'SL', 'PW', 'PL']].skew(axis = 1)
x['kurt'] = x[['SW', 'SL', 'PW', 'PL']].kurt(axis = 1)

# %%
x.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'mean', 'sum', 'skew', 'kurt'], dtype='object')

# %%
#Splitting the data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 2, test_size = 0.3)

# %%
#Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %% [markdown]
# # 3. Find out which classification model gives the best result to predict iris species.(also do random forest algorithm).

# %%
#Building the Model---Logistic Regression Algorithm

# %%
from sklearn.linear_model import LogisticRegression
logit_model = LogisticRegression()
logit_model.fit(x_train, y_train)
y_pred = logit_model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
print("Accuracy is: ", accuracy_score(y_test,y_pred))
print("Precision is: ", precision_score(y_test,y_pred, average = 'micro'))
print("Recall is: ", recall_score(y_test,y_pred,  average = 'micro'))
print("F1 score is: ", f1_score(y_test,y_pred,  average = 'micro'))
# Out:
# Accuracy is:  1.0
# Precision is:  1.0
# Recall is:  1.0
# F1 score is:  1.0

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[16,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  0, 12]], dtype=int64)

# %%
#Building the Model---KNN Algorithm

# %%
from sklearn.neighbors import KNeighborsClassifier
acc_values = []
neighbors = np.arange(3,15)
for k in neighbors:
    classifier = KNeighborsClassifier(n_neighbors = k, metric='minkowski')
    classifier.fit(x_train, y_train)
    y_pred =  classifier.predict(x_test)
    acc = accuracy_score(y_test, y_pred)
    acc_values.append(acc)

# %%
acc_values
# Out:
# [0.9512195121951219,
#  0.975609756097561,
#  0.926829268292683,
#  0.975609756097561,
#  0.975609756097561,
#  0.975609756097561,
#  0.975609756097561,
#  0.975609756097561,
#  0.975609756097561,
#  0.975609756097561,
#  0.975609756097561,
#  0.975609756097561]

# %%
plt.plot(neighbors, acc_values, 'o-')
plt.xlabel('K values')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
classifier = KNeighborsClassifier(n_neighbors = 5, metric='minkowski')
classifier.fit(x_train, y_train)
y_pred =  classifier.predict(x_test)

# %%
print("Accuracy is: ", accuracy_score(y_test,y_pred))
print("Precision is: ", precision_score(y_test,y_pred, average = 'micro'))
print("Recall is: ", recall_score(y_test,y_pred,  average = 'micro'))
print("F1 score is: ", f1_score(y_test,y_pred,  average = 'micro'))
# Out:
# Accuracy is:  0.926829268292683
# Precision is:  0.926829268292683
# Recall is:  0.926829268292683
# F1 score is:  0.926829268292683

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[16,  0,  0],
#        [ 0, 10,  3],
#        [ 0,  0, 12]], dtype=int64)

# %%
#Building the Model---Decision Tree Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model =DecisionTreeClassifier()
dt_model.fit(x_train,y_train)
y_pred=dt_model.predict(x_test)

# %%
print("Accuracy is: ", accuracy_score(y_test,y_pred))
print("Precision is: ", precision_score(y_test,y_pred, average = 'micro'))
print("Recall is: ", recall_score(y_test,y_pred,  average = 'micro'))
print("F1 score is: ", f1_score(y_test,y_pred,  average = 'micro'))
# Out:
# Accuracy is:  0.9512195121951219
# Precision is:  0.9512195121951219
# Recall is:  0.9512195121951219
# F1 score is:  0.9512195121951219

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[16,  0,  0],
#        [ 0, 12,  1],
#        [ 0,  1, 11]], dtype=int64)

# %%
#Building the Model---Support Vector Machine---Linear Kernel

# %%
from sklearn.svm import SVC
svm_linear = SVC(kernel = 'linear')
svm_linear.fit(x_train, y_train)
y_pred = svm_linear.predict(x_test)

# %%
print("Accuracy is: ", accuracy_score(y_test,y_pred))
print("Precision is: ", precision_score(y_test,y_pred, average = 'micro'))
print("Recall is: ", recall_score(y_test,y_pred,  average = 'micro'))
print("F1 score is: ", f1_score(y_test,y_pred,  average = 'micro'))
# Out:
# Accuracy is:  0.9512195121951219
# Precision is:  0.9512195121951219
# Recall is:  0.9512195121951219
# F1 score is:  0.9512195121951219

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[16,  0,  0],
#        [ 0, 11,  2],
#        [ 0,  0, 12]], dtype=int64)

# %%
#Building the Model---Support Vector Machine---Polynomial Kernel

# %%
svm_poly = SVC(kernel = 'poly', degree = 3)
svm_poly.fit(x_train,y_train)
y_pred = svm_poly.predict(x_test)

# %%
print("Accuracy is: ", accuracy_score(y_test,y_pred))
print("Precision is: ", precision_score(y_test,y_pred, average = 'micro'))
print("Recall is: ", recall_score(y_test,y_pred,  average = 'micro'))
print("F1 score is: ", f1_score(y_test,y_pred,  average = 'micro'))
# Out:
# Accuracy is:  0.9512195121951219
# Precision is:  0.9512195121951219
# Recall is:  0.9512195121951219
# F1 score is:  0.9512195121951219

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[15,  1,  0],
#        [ 0, 13,  0],
#        [ 0,  1, 11]], dtype=int64)

# %%
#Building the Model---Support Vector Machine---Radial Basis Function Kernel

# %%
svm_radial = SVC(kernel = 'rbf')
svm_radial.fit(x_train,y_train)
y_pred = svm_radial.predict(x_test)

# %%
print("Accuracy is: ", accuracy_score(y_test,y_pred))
print("Precision is: ", precision_score(y_test,y_pred, average = 'micro'))
print("Recall is: ", recall_score(y_test,y_pred,  average = 'micro'))
print("F1 score is: ", f1_score(y_test,y_pred,  average = 'micro'))
# Out:
# Accuracy is:  0.975609756097561
# Precision is:  0.975609756097561
# Recall is:  0.975609756097561
# F1 score is:  0.975609756097561

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[16,  0,  0],
#        [ 0, 12,  1],
#        [ 0,  0, 12]], dtype=int64)

# %%
#Building the Model---Rain Forest Classifier Algorithm

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
y_pred = rf.predict(x_test)

# %%
print("Accuracy is: ", accuracy_score(y_test,y_pred))
print("Precision is: ", precision_score(y_test,y_pred,  average = 'micro'))
print("Recall is: ", recall_score(y_test,y_pred,  average = 'micro'))
print("F1 score is: ", f1_score(y_test,y_pred, average = 'micro'))
# Out:
# Accuracy is:  0.9512195121951219
# Precision is:  0.9512195121951219
# Recall is:  0.9512195121951219
# F1 score is:  0.9512195121951219

# %%
confusion_matrix (y_test, y_pred)
# Out:
# array([[16,  0,  0],
#        [ 0, 11,  2],
#        [ 0,  0, 12]], dtype=int64)

# %%
#Feature Importance

# %%
pd.Series(rf.feature_importances_, index = x.columns).sort_values(ascending=False)*100
# Out:
# PL      24.038528
# PW      20.596217
# sum     17.463955
# kurt    16.207318
# mean    12.809892
# SL       4.422766
# SW       2.340787
# skew     2.120537
# dtype: float64

# %% [markdown]
# When comparing the f1 scores of the algorithms we can say that SVM algorithm with Radial Basis Function kernel lead to neither overfitting nor underfitting model for the classification of species of the iris flower according to the given dataset. Where in the case of logistic regression algorithm the predictions were overfitting. The least fitted among the tested algorithms was the KNN Algorithm.
